# %%
import shutil

# Define the source path of the file to be copied
source_file = 'csv-tiedostonluonti/detect2.py'

# Define the destination path where the file will be copied
destination_file = 'yolov5/detect2.py'

# Copy the file from the source to the destination
try:
    shutil.copy(source_file, destination_file)
    print(f'File copied successfully from {source_file} to {destination_file}.')
except IOError as e:
    print(f'Unable to copy file. {e}')
except Exception as e:
    print(f'Unexpected error: {e}')
# Out:
# File copied successfully from csv-tiedostonluonti/detect2.py to yolov5/detect2.py.

# %%
# !python yolov5/detect2.py --weights yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.50 --source data/kuvat --save-csv
                        # tähän vaihtaa exp(N) siihen millä mallilla suoritetaan #sekä tarvittaessa muokkaa polkua  #../kaivot
# Out:
# detect2: weights=['yolov5/runs/train/exp2/weights/best.pt'], source=data/kuvat, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-313-g712de55a Python-3.11.9 torch-2.2.2+cu121 CUDA:0 (Tesla V100-PCIE-12GB, 12060MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2961 /home/jovyan/courses/projekti3/projekti3/main/data/kuvat/100000_kultsieki.jpg: 640x384 (no detections), 87.8ms
# image 2/2961 /home/jovyan/courses/projekti3/projekti3/main/data/kuvat/100004_SMMH.jpg: 640x384 (no detections), 12.2ms
# ...
